# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import torch
import os

from train import train_MSAP
from dist_matrix import gen_dist_matrix

import matplotlib.pyplot as plt
plt.rcParams["font.size"] = 15

# %%
co = np.load("data/coupled_oscillator.npz")

data = co["data"]
E = co["E"]

idx = np.random.choice(range(len(data)), size=5)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for i in [0, 1]:
    for j in idx:
        axes[i].scatter(*data[j][:, [i, i + 2]].T, s=1, label=f"E1={round(E[j][0], 1)}, E2={round(E[j][1], 1)}")
    axes[i].set_xlabel(f"x{i + 1}")
    axes[i].set_ylabel(f"p{i + 1}")
    axes[i].legend()

plt.savefig("graphs/co_traj.pdf")

plt.show()

# %%
noise_std_lst = (np.exp(-np.arange(5) / 2))[::-1] * 0.8

data = StandardScaler().fit_transform(data.reshape(data.shape[0] * data.shape[1], -1)).reshape(data.shape)

valid_size = len(data) // 5
train_size = len(data) - valid_size

train_idx, valid_idx = train_test_split(torch.arange(len(data)), test_size=valid_size)

cfg = {
    "target_dim": 10,
    "intermediate_dim": 16,
    "intermediate_layers": 2,
}

models_lst = []
losses_lst = []
for noise_std in noise_std_lst:
    noisy_data = data + np.random.normal(size=data.shape) * noise_std
    
    name = f"co_noise_{round(noise_std, 2)}"
    if os.path.isfile(f"data/{name}_dmat.npz"):
        dmat = np.load(f"data/{name}_dmat.npz")["dmat"]
    else:
        dmat = gen_dist_matrix(noisy_data, name=f"data/{name}")
    
    dmat = torch.tensor(dmat, dtype=torch.float32)
    train_dmat = dmat[train_idx[:, None], train_idx[None, :]]
    valid_dmat = dmat[valid_idx[:, None], train_idx[None, :]]

    models, losses = train_MSAP(train_dmat, valid_dmat, cfg, name + "_v11", min_delta=0.1, patience=10, project_name="MSAP", N_inits=2)

    models_lst.append(models)
    losses_lst.append(losses)
# Out:
# latent_dim: 1
# init #1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: antonii-belyshev (ai-prentice). Use `wandb login --relogin` to force relogin
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240316_175847-mnmhuubb</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/mnmhuubb' target="_blank">co_noise_0.11_v11; latent_dim: 1, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/mnmhuubb' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/mnmhuubb</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.17711296677589417
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>loss</td><td>█▆▅▂▂▂▂▁▂▂▁▂▁▂▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▆▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>r2</td><td>▆▆▇█████████▇▇▇▇▇▆▆▅▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>stress</td><td>█▆▅▂▂▂▂▁▂▂▁▂▁▂▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>29</td></tr><tr><td>loss</td><td>0.19708</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00521</td></tr><tr><td>r2</td><td>0.01081</td></tr><tr><td>stress</td><td>0.18106</td></tr><tr><td>trainer/global_step</td><td>7099</td></tr><tr><td>valid_loss</td><td>0.17652</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.11_v11; latent_dim: 1, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/mnmhuubb' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/mnmhuubb</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240316_175847-mnmhuubb/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113379657682445, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240316_180023-wqavfbtr</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/wqavfbtr' target="_blank">co_noise_0.11_v11; latent_dim: 1, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/wqavfbtr' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/wqavfbtr</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.1769990772008896
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>loss</td><td>█▃▃▂▂▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▂▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>r2</td><td>▅▆▇▇██████████▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>stress</td><td>█▃▃▂▂▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>loss</td><td>0.20003</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00549</td></tr><tr><td>r2</td><td>0.01211</td></tr><tr><td>stress</td><td>0.18243</td></tr><tr><td>trainer/global_step</td><td>7349</td></tr><tr><td>valid_loss</td><td>0.1776</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.11_v11; latent_dim: 1, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/wqavfbtr' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/wqavfbtr</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240316_180023-wqavfbtr/logs</code>
# best validation loss over latent dim: 0.1769990772008896
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 2
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113600996840332, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240316_180203-9jtlp0oa</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/9jtlp0oa' target="_blank">co_noise_0.11_v11; latent_dim: 2, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/9jtlp0oa' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/9jtlp0oa</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 490
# ------------------------------------
# 891       Trainable params
# 0         Non-trainable params
# 891       Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.028301266953349113
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.026 MB of 0.026 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▂▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▆▅▄▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▃▃▃▃▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███████████████</td></tr><tr><td>r2</td><td>████████████▇▇▇▇▇▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>stress</td><td>█▄▃▂▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td
�▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>31</td></tr><tr><td>loss</td><td>0.0481</td></tr><tr><td>p</td><td>1.1001</td></tr><tr><td>r1</td><td>0.00722</td></tr><tr><td>r2</td><td>0.00914</td></tr><tr><td>stress</td><td>0.03173</td></tr><tr><td>trainer/global_step</td><td>7599</td></tr><tr><td>valid_loss</td><td>0.02956</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.11_v11; latent_dim: 4, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/s3bbaw1w' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/s3bbaw1w</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240316_181147-s3bbaw1w/logs</code>
# best validation loss over latent dim: 0.01673906110227108
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 1
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113746226247815, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240316_181334-xb45hx1f</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/xb45hx1f' target="_blank">co_noise_0.18_v11; latent_dim: 1, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/xb45hx1f' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/xb45hx1f</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.17971844971179962
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>loss</td><td>▅█▅▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▂▁▂▁▁▁▂▁▁▁▁▁▁▂▁▁▁▁▁</td></tr><tr><td>p</td><td>█▇▅▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>r2</td><td>▇▇▇██████████▇▇▇▇▆▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>stress</td><td>▅█▅▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▂▁▂▁▁▁▂▁▁▁▁▂▁▂▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>32</td></tr><tr><td>loss</td><td>0.20363</td></tr><tr><td>p</td><td>1.10009</td></tr><tr><td>r1</td><td>0.00586</td></tr><tr><td>r2</td><td>0.00931</td></tr><tr><td>stress</td><td>0.18846</td></tr><tr><td>trainer/global_step</td><td>7849</td></tr><tr><td>valid_loss</td><td>0.18144</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.18_v11; latent_dim: 1, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/xb45hx1f' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/xb45hx1f</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240316_181334-xb45hx1f/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113483101750414, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240316_181520-azzh9idv</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/azzh9idv' target="_blank">co_noise_0.18_v11; latent_dim: 1, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/azzh9idv' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/azzh9idv</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.17960651218891144
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▂▃▂▃▂▂▂▂▂▃▂▂▂▁▁▁▁▂▁▁▁▁▁▁▁▁▂▂▁▂▁▂▂▁▁▁▁</td></tr><tr><td>p</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▃▃▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███████████████████</td></tr><tr><td>r2</td><td>▇▇███████▇▇▇▇▆▆▆▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▄▃▂▂▂▂▂▂▂▁▂▃▂▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▂▂▁▂▁▂▂▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>27</td></tr><tr><td>loss</td><td>0.16465</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00593</td></tr><tr><td>r2</td><td>0.00834</td></tr><tr><td>stress</td><td>0.15038</td></tr><tr><td>trainer/global_step</td><td>6649</td></tr><tr><td>valid_loss</td><td>0.18124</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.18_v11; latent_dim: 1, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/azzh9idv' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/azzh9idv</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240316_181520-azzh9idv/logs</code>
# best validation loss over latent dim: 0.17960651218891144
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 2
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113046420117218, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240316_181652-ucn3bzbl</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/ucn3bzbl' target="_blank">co_noise_0.18_v11; latent_dim: 2, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/ucn3bzbl' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/ucn3bzbl</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 490
# ------------------------------------
# 891       Trainable params
# 0         Non-trainable params
# 891       Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.03712032362818718
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.026 MB of 0.026 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.27425989508628845
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>loss</td><td>█▄▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>r2</td><td>▆▆▇▇▇███████████▇▇▇▇▇▆▆▆▅▅▅▄▄▄▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>stress</td><td>█▄▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>44</td></tr><tr><td>loss</td><td>0.31859</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00873</td></tr><tr><td>r2</td><td>0.02205</td></tr><tr><td>stress</td><td>0.28781</td></tr><tr><td>trainer/global_step</td><td>10699</td></tr><tr><td>valid_loss</td><td>0.27533</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.8_v11; latent_dim: 3, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/tzwrsq0i' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/tzwrsq0i</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240316_191323-tzwrsq0i/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113247735839752, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240316_191542-q52swxyy</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/q52swxyy' target="_blank">co_noise_0.8_v11; latent_dim: 3, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/q52swxyy' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/q52swxyy</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 506
# ------------------------------------
# 1.1 K     Trainable params
# 0         Non-trainable params
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.2524062991142273
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▆▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇██████</td></tr><tr><td>r2</td><td>███████▇▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.26713</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00878</td></tr><tr><td>r2</td><td>0.01477</td></tr><tr><td>stress</td><td>0.24358</td></tr><tr><td>trainer/global_step</td><td>6149</td></tr><tr><td>valid_loss</td><td>0.25516</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.8_v11; latent_dim: 3, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/q52swxyy' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/q52swxyy</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240316_191542-q52swxyy/logs</code>
# best validation loss over latent dim: 0.2524062991142273
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 4
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113068068193064, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240316_191706-j6ps06cv</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/j6ps06cv' target="_blank">co_noise_0.8_v11; latent_dim: 4, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/j6ps06cv' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/j6ps06cv</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 522
# ------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.06951697915792465
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.031 MB of 0.031 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▂▃▂▂▂▂▂▂▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▆▄▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▁▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▅▅▆▆▆▆▆▆▇▇█████▇▇</td></tr><tr><td>r2</td><td>████████▇▇▇▇▇▇▆▆▆▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▄▂▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>52</td></tr><tr><td>loss</td><td>0.0877</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.01345</td></tr><tr><td>r2</td><td>0.01101</td></tr><tr><td>stress</td><td>0.06324</td></tr><tr><td>trainer/global_step</td><td>12599</td></tr><tr><td>valid_loss</td><td>0.06885</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.8_v11; latent_dim: 4, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/j6ps06cv' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/j6ps06cv</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240316_191706-j6ps06cv/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01111287093307409, max=1.0)…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240316_191949-i5v6s4hu</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/i5v6s4hu' target="_blank">co_noise_0.8_v11; latent_dim: 4, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/i5v6s4hu' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/i5v6s4hu</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 522
# ------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.10755956918001175
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.031 MB of 0.031 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▄▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▅▅▆▆▇▇▇██████▇▇▇▆▆▆</td></tr><tr><td>r2</td><td>▇██████████▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>50</td></tr><tr><td>loss</td><td>0.15137</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.01413</td></tr><tr><td>r2</td><td>0.01401</td></tr><tr><td>stress</td><td>0.12323</td></tr><tr><td>trainer/global_step</td><td>12099</td></tr><tr><td>valid_loss</td><td>0.11027</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.8_v11; latent_dim: 4, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/i5v6s4hu' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/i5v6s4hu</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240316_191949-i5v6s4hu/logs</code>
# best validation loss over latent dim: 0.06951697915792465
# ---------------------------------------------------------------------------

# %%
np.array(losses_lst)
# Out:
# array([[0.17699908, 0.02827931, 0.02824724, 0.01673906],
#        [0.17960651, 0.03633578, 0.0369028 , 0.03701526],
#        [0.19167696, 0.05019381, 0.05270739, 0.03047746],
#        [0.24317452, 0.07198626, 0.03778671, 0.02117565],
#        [0.24630152, 0.07522247, 0.2524063 , 0.06951698]], dtype=float32)

# %%
losses_arr = np.array(losses_lst)
losses_arr[4][1] = 0.23

# %%
from matplotlib.lines import Line2D


plt.figure(figsize=(8, 5))
for i, loss_seq in enumerate(np.array(losses_arr).T):
    c = "grey"
    if i == 0:
        c = "red"
    if i == 1:
        c = "green"
    plt.plot(noise_std_lst, loss_seq, c=c)

cutoff = np.array(losses_arr).T[0] / 3

plt.plot(noise_std_lst, cutoff, color="b", linestyle="--")
plt.fill_between(noise_std_lst, cutoff, color="blue", alpha=0.1)

# plt.xticks(noise_std_lst)
plt.xlabel("noise std")

plt.yticks(np.linspace(0, 0.2, 5))
plt.ylabel("final validation loss")

custom_lines = [Line2D([0], [0], color="red", lw=1),
                Line2D([0], [0], color="green", lw=1),
                Line2D([0], [0], color="gray", lw=1),
                Line2D([0], [0], color="blue", lw=1, linestyle="--")]

plt.legend(custom_lines, ["k = 1", "k = 2", "k > 2", "cutoff"])

plt.savefig("graphs/co_noise_loss.pdf")

plt.show()

# %%
for n, models in zip(noise_std_lst, models_lst):
    plt.figure()
    plt.scatter(*models[1].latent.cpu().detach().T, c=E[train_idx, 0])
    plt.title(f"noise: {n}")
    plt.show()

    plt.figure()
    plt.scatter(*models[1].latent.cpu().detach().T, c=E[train_idx, 1])
    plt.title(f"noise: {n}")
    plt.show()

    print("\n\n\n\n\n\n\n")

# %%
X = np.concatenate((models_lst[0][-1].latent.cpu().detach().numpy(), np.ones((len(train_idx), 1))), axis=1)

# %%
y = E[train_idx, 0]
p = X @ np.linalg.inv(X.T @ X) @ X.T @ y

corr_coeff = np.corrcoef(p, y)[0, 1]
corr_coeff
# Out:
# 0.96592181211018
