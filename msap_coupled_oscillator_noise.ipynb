# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import torch

from train import train_MSAP
from dist_matrix import gen_dist_matrix

import matplotlib.pyplot as plt
plt.rcParams["font.size"] = 15

# %%
co = np.load("data/coupled_oscillator.npz")

data = co["data"]
E = co["E"]

idx = np.random.choice(range(len(data)), size=5)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for i in [0, 1]:
    for j in idx:
        axes[i].scatter(*data[j][:, [i, i + 2]].T, s=1, label=f"E1={round(E[j][0], 1)}, E2={round(E[j][1], 1)}")
    axes[i].set_xlabel(f"x{i + 1}")
    axes[i].set_ylabel(f"p{i + 1}")
    axes[i].legend()

plt.savefig("graphs/co_traj.pdf")

plt.show()

# %%
noise_std_lst = np.linspace(0.1, 0.5, 5)

data = StandardScaler().fit_transform(data.reshape(data.shape[0] * data.shape[1], -1)).reshape(data.shape)

cfg = {
    "target_dim": 10,
    "intermediate_dim": 16,
    "intermediate_layers": 2,
}

models_lst = []
losses_lst = []
for noise_std in noise_std_lst:
    noisy_data = data + np.random.normal(size=data.shape) * noise_std
    
    name = f"co_noise_{round(noise_std, 1)}"
    dmat = gen_dist_matrix(noisy_data, name=f"data/{name}")

    valid_size = len(dmat) // 5
    train_size = len(dmat) - valid_size

    train_idx, valid_idx = train_test_split(torch.arange(len(dmat)), test_size=valid_size)

    dmat = torch.tensor(dmat, dtype=torch.float32)
    train_dmat = dmat[train_idx[:, None], train_idx[None, :]]
    valid_dmat = dmat[valid_idx[:, None], train_idx[None, :]]

    models, losses = train_MSAP(train_dmat, valid_dmat, cfg, name, min_delta=0.1, patience=50, project_name="MSAP", N_inits=2)

    models_lst.append(models)
    losses_lst.append(losses)
# Out:
# Finished preprocessing 200 events in 0.0038s
#    1990 / 19900  EMDs computed  -  10.00% completed - 30.919s
#    3980 / 19900  EMDs computed  -  20.00% completed - 61.054s
#    5970 / 19900  EMDs computed  -  30.00% completed - 91.736s
#    7960 / 19900  EMDs computed  -  40.00% completed - 127.554s
#    9950 / 19900  EMDs computed  -  50.00% completed - 161.463s
#   11940 / 19900  EMDs computed  -  60.00% completed - 192.447s
#   13930 / 19900  EMDs computed  -  70.00% completed - 221.923s
#   15920 / 19900  EMDs computed  -  80.00% completed - 251.274s
#   17910 / 19900  EMDs computed  -  90.00% completed - 281.363s
#   19900 / 19900  EMDs computed  - 100.00% completed - 310.852s
# latent_dim: 1
# init #1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: antonii-belyshev (ai-prentice). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_195211-maw5ro98</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/maw5ro98' target="_blank">co_noise_0.1; latent_dim: 1, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/maw5ro98' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/maw5ro98</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.16002368927001953
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▂▂▂▁▁▁▁▂▁▁▂▁▁▁▁▁▂▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▃▄▅▅▆▆▇▇▇██████████▇▇▇▆▆▆▅▅▅▅▄▄▄▄▄▄▄▄▄</td></tr><tr><td>r2</td><td>▇█████▇▇▆▅▅▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▂▂▂▁▂▁▁▁▁▁▁▁▂▁▁▁▁▁▂▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>86</td></tr><tr><td>loss</td><td>0.19314</td></tr><tr><td>p</td><td>1.1003</td></tr><tr><td>r1</td><td>0.00416</td></tr><tr><td>r2</td><td>0.00731</td></tr><tr><td>stress</td><td>0.18167</td></tr><tr><td>trainer/global_step</td><td>20699</td></tr><tr><td>valid_loss</td><td>0.16579</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.1; latent_dim: 1, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/maw5ro98' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/maw5ro98</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_195211-maw5ro98/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113622453477648, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_195747-2q48teyw</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/2q48teyw' target="_blank">co_noise_0.1; latent_dim: 1, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/2q48teyw' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/2q48teyw</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.1608215719461441
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▄▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▂▃▃▄▄▄▅▅▆▆▆▇▇▇██████▇▇▇▇▆▆▆▅▅▄▄▄▄▃▃▃▃▃</td></tr><tr><td>r2</td><td>▆▇███████▇▇▇▆▆▆▅▅▅▄▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▄▄▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>75</td></tr><tr><td>loss</td><td>0.20953</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00401</td></tr><tr><td>r2</td><td>0.00747</td></tr><tr><td>stress</td><td>0.19806</td></tr><tr><td>trainer/global_step</td><td>18049</td></tr><tr><td>valid_loss</td><td>0.1655</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.1; latent_dim: 1, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/2q48teyw' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/2q48teyw</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_195747-2q48teyw/logs</code>
# best validation loss over latent dim: 0.16002368927001953
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 2
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011187281749314732, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_200240-2rslar7p</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/2rslar7p' target="_blank">co_noise_0.1; latent_dim: 2, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/2rslar7p' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/2rslar7p</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 490
# ------------------------------------
# 891       Trainable params
# 0         Non-trainable params
# 891       Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.018063915893435478
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.026 MB of 0.026 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▄▄▃▄▄▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▃▄▄▄▄▆▇▇▆▆▆▆▆▆▆▆▆▇████████████████████</td></tr><tr><td>r2</td><td>█▇▇▆▅▅▄▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▅▄▄▃▄▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▄▄▃▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>139</td></tr><tr><td>loss</td><td>0.05032</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00908</td></tr><tr><td>r2</td><td>0.00565</td></tr><tr><td>stress</td><td>0.0356</td></tr><tr><td>trainer/global_step</td><td>33299</td></tr><tr><td>valid_loss</td><td>0.01923</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.1; latent_dim: 2, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/2rslar7p' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/2rslar7p</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_200240-2rslar7p/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112935758299297, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_201128-u1pwnzzm</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/u1pwnzzm' target="_blank">co_noise_0.1; latent_dim: 2, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/u1pwnzzm' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/u1pwnzzm</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 490
# ------------------------------------
# 891       Trainable params
# 0         Non-trainable params
# 891       Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.024998171254992485
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.026 MB of 0.026 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▂▃▃▄▄▄▅▅▅▆▆▇▇████████▇▇▇▆▆▆▆▆▅▅▅▅▅▅▅▅▅</td></tr><tr><td>r2</td><td>▇███████▇▇▇▆▆▅▅▅▄▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>81</td></tr><tr><td>loss</td><td>0.04307</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00536</td></tr><tr><td>r2</td><td>0.0055</td></tr><tr><td>stress</td><td>0.03221</td></tr><tr><td>trainer/global_step</td><td>19499</td></tr><tr><td>valid_loss</td><td>0.02642</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.1; latent_dim: 2, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/u1pwnzzm' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/u1pwnzzm</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_201128-u1pwnzzm/logs</code>
# best validation loss over latent dim: 0.018063915893435478
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 3
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113617672688432, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_201640-7o0oj6wb</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/7o0oj6wb' target="_blank">co_noise_0.1; latent_dim: 3, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/7o0oj6wb' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/7o0oj6wb</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 506
# ------------------------------------
# 1.1 K     Trainable params
# 0         Non-trainable params
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.015296380035579205
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▃▃▃▄▅▆▆▆▇▇██████▇▇▇▇▆▆▆▆▆▆▆▅▅▅▅▅▅▅▅</td></tr><tr><td>r2</td><td>████▇▇▇▆▆▅▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>79</td></tr><tr><td>loss</td><td>0.03218</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00721</td></tr><tr><td>r2</td><td>0.0053</td></tr><tr><td>stress</td><td>0.01967</td></tr><tr><td>trainer/global_step</td><td>18999</td></tr><tr><td>valid_loss</td><td>0.01766</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.1; latent_dim: 3, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/7o0oj6wb' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/7o0oj6wb</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_201640-7o0oj6wb/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01111350322349204, max=1.0)…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_202144-20j21qpt</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/20j21qpt' target="_blank">co_noise_0.1; latent_dim: 3, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/20j21qpt' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/20j21qpt</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 506
# ------------------------------------
# 1.1 K     Trainable params
# 0         Non-trainable params
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.024792032316327095
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>loss</td><td>█▅▆▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▃▄▅▆▆▇▇▇███████████▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▅</td></tr><tr><td>r2</td><td>███▇▇▆▆▅▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▅▆▄▂▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>73</td></tr><tr><td>loss</td><td>0.04758</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00541</td></tr><tr><td>r2</td><td>0.00561</td></tr><tr><td>stress</td><td>0.03656</td></tr><tr><td>trainer/global_step</td><td>17599</td></tr><tr><td>valid_loss</td><td>0.02865</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.1; latent_dim: 3, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/20j21qpt' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/20j21qpt</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_202144-20j21qpt/logs</code>
# best validation loss over latent dim: 0.015296380035579205
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 4
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113103768891758, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_202627-nwfzhp55</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/nwfzhp55' target="_blank">co_noise_0.1; latent_dim: 4, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/nwfzhp55' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/nwfzhp55</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 522
# ------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.02551959827542305
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.031 MB of 0.031 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▃▃▃▄▄▅▆▇█████▇▇▇▆▆▅▅▅▅▄▄▄▄▄▄▄▄▄▄▄▄▄▄</td></tr><tr><td>r2</td><td>███▇▇▆▆▅▅▄▄▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>97</td></tr><tr><td>loss</td><td>0.03828</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00551</td></tr><tr><td>r2</td><td>0.0057</td></tr><tr><td>stress</td><td>0.02707</td></tr><tr><td>trainer/global_step</td><td>23299</td></tr><tr><td>valid_loss</td><td>0.03143</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.1; latent_dim: 4, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/nwfzhp55' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/nwfzhp55</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_202627-nwfzhp55/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112917421592606, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_203246-ptqj1mxk</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/ptqj1mxk' target="_blank">co_noise_0.1; latent_dim: 4, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/ptqj1mxk' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/ptqj1mxk</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 522
# ------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.015054197981953621
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.031 MB of 0.031 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▇▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁</td></tr><tr><td>r1</td><td>▁▁▂▃▃▄▅▆▆▇▇████▇▇▇▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>r2</td><td>██▇▆▆▅▅▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▇▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▆▄▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>110</td></tr><tr><td>loss</td><td>0.03081</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00718</td></tr><tr><td>r2</td><td>0.00548</td></tr><tr><td>stress</td><td>0.01816</td></tr><tr><td>trainer/global_step</td><td>26399</td></tr><tr><td>valid_loss</td><td>0.01647</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.1; latent_dim: 4, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/ptqj1mxk' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/ptqj1mxk</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_203246-ptqj1mxk/logs</code>
# best validation loss over latent dim: 0.015054197981953621
# ---------------------------------------------------------------------------
#
#
#
#
# Finished preprocessing 200 events in 0.0027s
#    1990 / 19900  EMDs computed  -  10.00% completed - 31.931s
#    3980 / 19900  EMDs computed  -  20.00% completed - 63.952s
#    5970 / 19900  EMDs computed  -  30.00% completed - 98.453s
#    7960 / 19900  EMDs computed  -  40.00% completed - 138.991s
#    9950 / 19900  EMDs computed  -  50.00% completed - 175.344s
#   11940 / 19900  EMDs computed  -  60.00% completed - 210.831s
#   13930 / 19900  EMDs computed  -  70.00% completed - 243.260s
#   15920 / 19900  EMDs computed  -  80.00% completed - 274.869s
#   17910 / 19900  EMDs computed  -  90.00% completed - 307.201s
#   19900 / 19900  EMDs computed  - 100.00% completed - 341.658s
# latent_dim: 1
# init #1
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_204537-z08kuolu</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/z08kuolu' target="_blank">co_noise_0.2; latent_dim: 1, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/z08kuolu' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/z08kuolu</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.1834336519241333
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>loss</td><td>█▂▃▂▂▂▂▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▃▃▄▄▅▆▆▆▇▇██████████▇▇▇▆▆▆▅▅▅▅▄▄▄▄▄▄▄▃</td></tr><tr><td>r2</td><td>▇████▇▇▆▆▅▅▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▂▃▂▂▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>72</td></tr><tr><td>loss</td><td>0.23145</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00439</td></tr><tr><td>r2</td><td>0.00743</td></tr><tr><td>stress</td><td>0.21962</td></tr><tr><td>trainer/global_step</td><td>17349</td></tr><tr><td>valid_loss</td><td>0.18682</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.2; latent_dim: 1, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/z08kuolu' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/z08kuolu</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_204537-z08kuolu/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113447654578421, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_205022-fp1ji2ns</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/fp1ji2ns' target="_blank">co_noise_0.2; latent_dim: 1, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/fp1ji2ns' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/fp1ji2ns</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.18365880846977234
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▃▂▂▂▂▁▂▁▁▂▁▂▂▁▂▂▂▂▂▁▁▂▁▂▁▂▂▂▁▂▂▁▁▂▁▂▁</td></tr><tr><td>p</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▆▁</td></tr><tr><td>r1</td><td>▁▂▃▄▅▆▆▇▇▇██████████▇▇▇▆▆▆▆▅▅▅▅▅▅▄▄▄▄▃▃▄</td></tr><tr><td>r2</td><td>████▇▇▆▅▅▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▂▂▂▂▂▂▂▁▂▁▁▂▁▂▁▁▂▂▂▂▂▁▁▂▁▂▁▂▂▂▁▂▂▁▁▂▁▂▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▆▅▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>61</td></tr><tr><td>loss</td><td>0.18231</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00436</td></tr><tr><td>r2</td><td>0.00741</td></tr><tr><td>stress</td><td>0.17054</td></tr><tr><td>trainer/global_step</td><td>14749</td></tr><tr><td>valid_loss</td><td>0.18694</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.2; latent_dim: 1, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/fp1ji2ns' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/fp1ji2ns</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_205022-fp1ji2ns/logs</code>
# best validation loss over latent dim: 0.1834336519241333
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 2
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112966595424547, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_205427-1u4g6f03</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/1u4g6f03' target="_blank">co_noise_0.2; latent_dim: 2, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/1u4g6f03' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/1u4g6f03</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 490
# ------------------------------------
# 891       Trainable params
# 0         Non-trainable params
# 891       Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.03793508931994438
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.026 MB of 0.026 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 506
# ------------------------------------
# 1.1 K     Trainable params
# 0         Non-trainable params
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.027003152295947075
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▃▃▄▅▅▆▆▆▆▆▆▆▅▅▅▅▅▆▇▆▇████████▇▇▇▇▇▇</td></tr><tr><td>r2</td><td>████▇▇▆▆▅▄▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>114</td></tr><tr><td>loss</td><td>0.06244</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.01201</td></tr><tr><td>r2</td><td>0.00722</td></tr><tr><td>stress</td><td>0.04321</td></tr><tr><td>trainer/global_step</td><td>27349</td></tr><tr><td>valid_loss</td><td>0.03614</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.5; latent_dim: 3, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/z2fjlgzc' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/z2fjlgzc</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_234716-z2fjlgzc/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112809429566066, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231119_235448-rlftvztp</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/rlftvztp' target="_blank">co_noise_0.5; latent_dim: 3, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/rlftvztp' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/rlftvztp</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 506
# ------------------------------------
# 1.1 K     Trainable params
# 0         Non-trainable params
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.026061035692691803
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▄▃▃▃▃▃▂▂▂▂▂▂▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁█▁▁▁▂▁▁▁▁▁▃▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▂▂▃▃▃▃▂▂▃▅▅▇▇▇▇▇▇▇▇████████████████</td></tr><tr><td>r2</td><td>█▇▆▄▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▆▄▃▄▃▃▃▂▂▂▂▂▂▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▄▄▄▄▄▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>158</td></tr><tr><td>loss</td><td>0.04878</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.01569</td></tr><tr><td>r2</td><td>0.00699</td></tr><tr><td>stress</td><td>0.02609</td></tr><tr><td>trainer/global_step</td><td>37799</td></tr><tr><td>valid_loss</td><td>0.0272</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.5; latent_dim: 3, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/rlftvztp' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/rlftvztp</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231119_235448-rlftvztp/logs</code>
# best validation loss over latent dim: 0.026061035692691803
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 4
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113239990340338, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231120_000527-wvip2mbt</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/wvip2mbt' target="_blank">co_noise_0.5; latent_dim: 4, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/wvip2mbt' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/wvip2mbt</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 522
# ------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.027630947530269623
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.031 MB of 0.031 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▂▂▃▃▃▃▃▄▄▅▅▅▆▆▆▆▆▅▅▅▅▅▅▅▅▄▄▅▅▇▇▇▇██</td></tr><tr><td>r2</td><td>███▇▇▆▆▅▅▄▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▆▃▂▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>88</td></tr><tr><td>loss</td><td>0.05746</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.0144</td></tr><tr><td>r2</td><td>0.00725</td></tr><tr><td>stress</td><td>0.0358</td></tr><tr><td>trainer/global_step</td><td>21149</td></tr><tr><td>valid_loss</td><td>0.03435</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.5; latent_dim: 4, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/wvip2mbt' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/wvip2mbt</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231120_000527-wvip2mbt/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113052401277754, max=1.0…
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20231120_001129-xfnp670v</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/xfnp670v' target="_blank">co_noise_0.5; latent_dim: 4, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/xfnp670v' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/xfnp670v</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 522
# ------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.0258514154702425
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.031 MB of 0.031 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▅▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▃▃▄▅▆▆▆▅▅▅▄▅▆▅▄▄▄▇▇▇▇██▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>r2</td><td>██▇▆▅▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>148</td></tr><tr><td>loss</td><td>0.04859</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.01333</td></tr><tr><td>r2</td><td>0.00716</td></tr><tr><td>stress</td><td>0.0281</td></tr><tr><td>trainer/global_step</td><td>35449</td></tr><tr><td>valid_loss</td><td>0.02705</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.5; latent_dim: 4, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/xfnp670v' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/xfnp670v</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231120_001129-xfnp670v/logs</code>
# best validation loss over latent dim: 0.0258514154702425
# ---------------------------------------------------------------------------

# %%
from matplotlib.lines import Line2D


for i, loss_seq in enumerate(np.array(losses_lst).T):
    c = "grey"
    if i == 0:
        c = "red"
    if i == 1:
        c = "green"
    plt.plot(noise_std_lst, loss_seq, c=c)

plt.yticks(np.linspace(0, 0.2, 5))
plt.xlabel("noise std")
plt.ylabel("final validation loss")

custom_lines = [Line2D([0], [0], color="red", lw=1),
                Line2D([0], [0], color="green", lw=1),
                Line2D([0], [0], color="gray", lw=1)]

plt.legend(custom_lines, ["k = 1", "k = 2", "k > 1"])

plt.show()
