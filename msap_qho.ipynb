# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import torch

from train import train_MSAP
from dist_matrix import gen_dist_matrix

import matplotlib.pyplot as plt
plt.rcParams["font.size"] = 15

# %%
qho = np.load("data/quantum_ho.npz")

data = qho["data"]
x0 = qho["x0"].T[0]

plt.figure(figsize=(5, 5))
idx = np.argsort(x0)[(np.arange(5) * (len(x0) - 1) / 4).astype(int)]
for i in idx:
    plt.scatter(*data[i].T, label=f"x0 = {round(x0[i], 2)}", s=1)

plt.legend()

plt.xlabel("x")
plt.ylabel("p")

plt.savefig("graphs/ho_traj.pdf")

plt.show()

# %%
# data = StandardScaler().fit_transform(data.reshape(data.shape[0] * data.shape[1], -1)).reshape(data.shape)
# dmat = gen_dist_matrix(data, name="data/qho")
dmat = np.load("data/qho_dmat.npz")["dmat"]

valid_size = len(dmat) // 5
train_size = len(dmat) - valid_size

train_idx, valid_idx = train_test_split(torch.arange(len(dmat)), test_size=valid_size)

dmat = torch.tensor(dmat, dtype=torch.float32)
train_dmat = dmat[train_idx[:, None], train_idx[None, :]]
valid_dmat = dmat[valid_idx[:, None], train_idx[None, :]]

# %%
cfg = {
    "target_dim": 5,
    "intermediate_dim": 8,
    "intermediate_layers": 2,
}

models_qho, losses_qho = train_MSAP(train_dmat, valid_dmat, cfg, "qho", min_delta=0.1, patience=50, project_name="MSAP", N_inits=2)

# %%
# to plot this graph you have to download the validation loss data from the wandb to the data folder


import pandas as pd
from matplotlib.lines import Line2D

learning_curves = pd.read_csv("data/qho_learning_curves.csv")

plt.figure(figsize=(8, 5))
epoch = learning_curves["epoch"]
for i in range(1, 5):
    c = "green" if i == 1 else "black"
    alpha = 1 if i == 1 else 0.2
    for init in range(1, 3):
        valid_loss = learning_curves[f"qho; latent_dim: {i}, init #{init} - valid_loss"]
        plt.plot(epoch, valid_loss, c=c, alpha=alpha)

custom_lines = [Line2D([0], [0], color="green", lw=1),
                Line2D([0], [0], color="gray", lw=1)]

plt.legend(custom_lines, ["k = 1", "k > 1"])

plt.ylim(0, 0.02)

plt.xlabel("epoch")
plt.ylabel("validation loss")

plt.savefig("graphs/qho_learning_curves.pdf", bbox_inches="tight")

plt.show()

# %%
model1d = models_qho[0]

plt.figure()
plt.scatter(model1d.latent.cpu().detach().T[0], [np.zeros_like(train_idx)], c=x0[train_idx])
plt.xlabel("1d latent coordinate")
plt.gca().yaxis.set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.xticks([])
plt.title("Colored by energy")
plt.colorbar()
# plt.savefig("graphs/qho_latent1d.pdf")

model2d = models_qho[1]

plt.figure()
plt.scatter(*model2d.latent.cpu().detach().T, c=x0[train_idx])
plt.xlabel(f"2d latent coordinate #1")
plt.ylabel(f"2d latent coordinate #2")
plt.title(f"colored by energy")
plt.colorbar()
# plt.savefig("graphs/qho_latent2d.pdf")

plt.show()

# np.savez("qho_results.npz", latent1d=model1d.latent.cpu().detach(), latent2d=model1d.latent.cpu().detach(), E=E[train_idx])
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
N = 20

valid_size = N // 5
train_size = N - valid_size

train_idx, valid_idx = train_test_split(torch.arange(N), test_size=valid_size)

train_dmat = dmat[train_idx[:, None], train_idx[None, :]]
valid_dmat = dmat[valid_idx[:, None], train_idx[None, :]]

cfg = {
    "target_dim": 5,
    "intermediate_dim": 8,
    "intermediate_layers": 2,
    "batch_size": 8,
}

models_qho, losses_qho = train_MSAP(train_dmat, valid_dmat, cfg, "qho_small", min_delta=0.1, patience=200, project_name="MSAP", N_inits=2)
# Out:
# latent_dim: 1
# init #1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: antonii-belyshev (ai-prentice). Use `wandb login --relogin` to force relogin
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240313_075107-dfxzg6dv</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/dfxzg6dv' target="_blank">qho_small; latent_dim: 1, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/dfxzg6dv' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/dfxzg6dv</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 133
# ------------------------------------
# 154       Trainable params
# 0         Non-trainable params
# 154       Total params
# 0.001     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py:1933: PossibleUserWarning: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.0028912601992487907
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.018 MB of 0.018 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▄▄▁▂▂▂▁▂▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▂▂▂▃▃▃▃▃▄▄▄▅▅▆▆▆▇▇▇████████████▇▇▇▇▇▇▇</td></tr><tr><td>r2</td><td>▅▆▇▇▇██████▇▇▇▇▇▇▇██████▇▇▆▅▅▄▄▃▃▂▂▂▂▂▁▁</td></tr><tr><td>stress</td><td>█▃▄▄▁▂▂▂▁▂▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>999</td></tr><tr><td>loss</td><td>0.01618</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00519</td></tr><tr><td>r2</td><td>0.00158</td></tr><tr><td>stress</td><td>0.0094</td></tr><tr><td>trainer/global_step</td><td>15999</td></tr><tr><td>valid_loss</td><td>0.00599</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">qho_small; latent_dim: 1, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/dfxzg6dv' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/dfxzg6dv</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240313_075107-dfxzg6dv/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112877141891254, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240313_075436-39hat1rf</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/39hat1rf' target="_blank">qho_small; latent_dim: 1, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/39hat1rf' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/39hat1rf</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 133
# ------------------------------------
# 154       Trainable params
# 0         Non-trainable params
# 154       Total params
# 0.001     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py:1933: PossibleUserWarning: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.0036393264308571815
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.018 MB of 0.018 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇███████████</td></tr><tr><td>r2</td><td>▂▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇███████▇▇▇▆▅▄▄▃▂▁</td></tr><tr><td>stress</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>999</td></tr><tr><td>loss</td><td>0.01531</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00559</td></tr><tr><td>r2</td><td>0.00187</td></tr><tr><td>stress</td><td>0.00785</td></tr><tr><td>trainer/global_step</td><td>15999</td></tr><tr><td>valid_loss</td><td>0.00493</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">qho_small; latent_dim: 1, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/39hat1rf' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/39hat1rf</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240313_075436-39hat1rf/logs</code>
# best validation loss over latent dim: 0.0028912601992487907
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 2
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113285625146494, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240313_075756-u68c0rzp</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/u68c0rzp' target="_blank">qho_small; latent_dim: 2, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/u68c0rzp' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/u68c0rzp</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 141
# ------------------------------------
# 182       Trainable params
# 0         Non-trainable params
# 182       Total params
# 0.001     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py:1933: PossibleUserWarning: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.003289925865828991
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.018 MB of 0.018 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▁▂▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▇▇▇███████████▇▇▇▇▇▆▆▆▆</td></tr><tr><td>r2</td><td>▇▇██████████▇▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▁▁</td></tr><tr><td>stress</td><td>█▃▁▂▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>999</td></tr><tr><td>loss</td><td>0.01572</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00564</td></tr><tr><td>r2</td><td>0.00206</td></tr><tr><td>stress</td><td>0.00803</td></tr><tr><td>trainer/global_step</td><td>15999</td></tr><tr><td>valid_loss</td><td>0.00506</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">qho_small; latent_dim: 2, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/u68c0rzp' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/u68c0rzp</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240313_075756-u68c0rzp/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113186563468642, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240313_080114-2w8sn2wp</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/2w8sn2wp' target="_blank">qho_small; latent_dim: 2, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/2w8sn2wp' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/2w8sn2wp</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 141
# ------------------------------------
# 182       Trainable params
# 0         Non-trainable params
# 182       Total params
# 0.001     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py:1933: PossibleUserWarning: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.0027204882353544235
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.018 MB of 0.018 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▂▂▃▃▃▃▄▄▄▄▅▅▅▆▆▆▇▇▇▇███████████████▇▇▇</td></tr><tr><td>r2</td><td>▆▇▇████████████████▇▇▆▆▅▅▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>999</td></tr><tr><td>loss</td><td>0.0112</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00612</td></tr><tr><td>r2</td><td>0.00188</td></tr><tr><td>stress</td><td>0.00321</td></tr><tr><td>trainer/global_step</td><td>15999</td></tr><tr><td>valid_loss</td><td>0.00471</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">qho_small; latent_dim: 2, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/2w8sn2wp' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/2w8sn2wp</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240313_080114-2w8sn2wp/logs</code>
# best validation loss over latent dim: 0.0027204882353544235
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 3
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113046668469906, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240313_080429-pnc4a643</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/pnc4a643' target="_blank">qho_small; latent_dim: 3, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/pnc4a643' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/pnc4a643</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 149
# ------------------------------------
# 210       Trainable params
# 0         Non-trainable params
# 210       Total params
# 0.001     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py:1933: PossibleUserWarning: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.0025983478408306837
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.018 MB of 0.018 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▇▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▆▆▆▇▇███████████▇▇▇</td></tr><tr><td>r2</td><td>▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████▇▇▆▆▅▅▄▃▃▂▂▁</td></tr><tr><td>stress</td><td>█▇▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>999</td></tr><tr><td>loss</td><td>0.01422</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00769</td></tr><tr><td>r2</td><td>0.00305</td></tr><tr><td>stress</td><td>0.00348</td></tr><tr><td>trainer/global_step</td><td>15999</td></tr><tr><td>valid_loss</td><td>0.00321</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">qho_small; latent_dim: 3, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/pnc4a643' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/pnc4a643</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240313_080429-pnc4a643/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113226677601536, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240313_080743-dnxyg6l5</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/dnxyg6l5' target="_blank">qho_small; latent_dim: 3, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/dnxyg6l5' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/dnxyg6l5</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 149
# ------------------------------------
# 210       Trainable params
# 0         Non-trainable params
# 210       Total params
# 0.001     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py:1933: PossibleUserWarning: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.0035635950043797493
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.018 MB of 0.018 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▇▂▂▂▁▂▂▂▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▆▆▆▇▇▇▇▇█████████████▇▇</td></tr><tr><td>r2</td><td>▆▆▇▇▇██████████▇▇▇▇▇▇▇▇▆▆▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▇▂▂▂▁▂▂▂▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>965</td></tr><tr><td>loss</td><td>0.01146</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00588</td></tr><tr><td>r2</td><td>0.00256</td></tr><tr><td>stress</td><td>0.00302</td></tr><tr><td>trainer/global_step</td><td>15449</td></tr><tr><td>valid_loss</td><td>0.00608</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">qho_small; latent_dim: 3, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/dnxyg6l5' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/dnxyg6l5</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240313_080743-dnxyg6l5/logs</code>
# best validation loss over latent dim: 0.0025983478408306837
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 4
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113095402510629, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240313_081056-il969yce</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/il969yce' target="_blank">qho_small; latent_dim: 4, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/il969yce' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/il969yce</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 157
# ------------------------------------
# 238       Trainable params
# 0         Non-trainable params
# 238       Total params
# 0.001     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py:1933: PossibleUserWarning: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.0034491135738790035
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.019 MB of 0.019 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▁▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▄▅▅▆▇▇▇▇████████████▇▇▇▇▆▆▆▆</td></tr><tr><td>r2</td><td>▇▇▇▇▇▇▇▇████████████▇▇▆▆▆▅▄▄▄▃▃▂▂▂▂▂▁▁▁▁</td></tr><tr><td>stress</td><td>█▄▁▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>903</td></tr><tr><td>loss</td><td>0.02899</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00643</td></tr><tr><td>r2</td><td>0.00244</td></tr><tr><td>stress</td><td>0.02012</td></tr><tr><td>trainer/global_step</td><td>14449</td></tr><tr><td>valid_loss</td><td>0.00563</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">qho_small; latent_dim: 4, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/il969yce' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/il969yce</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240313_081056-il969yce/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113579767859644, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240313_081351-04x3jc6i</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/04x3jc6i' target="_blank">qho_small; latent_dim: 4, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/04x3jc6i' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/04x3jc6i</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 157
# ------------------------------------
# 238       Trainable params
# 0         Non-trainable params
# 238       Total params
# 0.001     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py:1933: PossibleUserWarning: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.0035354676656425
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.019 MB of 0.019 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▅▂▁▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▆▇▇▇▇██████████</td></tr><tr><td>r2</td><td>▆▇▇▇▇████████████▇▇▇▇▇▇▇▇▆▆▆▅▄▄▄▃▃▃▂▂▂▁▁</td></tr><tr><td>stress</td><td>█▃▅▂▁▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>999</td></tr><tr><td>loss</td><td>0.02434</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.0075</td></tr><tr><td>r2</td><td>0.00274</td></tr><tr><td>stress</td><td>0.01411</td></tr><tr><td>trainer/global_step</td><td>15999</td></tr><tr><td>valid_loss</td><td>0.00487</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">qho_small; latent_dim: 4, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/04x3jc6i' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/04x3jc6i</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240313_081351-04x3jc6i/logs</code>
# best validation loss over latent dim: 0.0034491135738790035
# ---------------------------------------------------------------------------

# %%
# to plot this graph you have to download the validation loss data from the wandb to the data folder


import pandas as pd
from matplotlib.lines import Line2D

learning_curves = pd.read_csv("data/qho_small_learning_curves.csv")

plt.figure(figsize=(8, 5))
epoch = learning_curves["epoch"]
for i in range(1, 5):
    c = "green" if i == 1 else "black"
    alpha = 1 if i == 1 else 0.2
    for init in range(1, 3):
        valid_loss = learning_curves[f"qho_small; latent_dim: {i}, init #{init} - valid_loss"]
        plt.plot(epoch, valid_loss, c=c, alpha=alpha)

custom_lines = [Line2D([0], [0], color="green", lw=1),
                Line2D([0], [0], color="gray", lw=1)]

plt.legend(custom_lines, ["k = 1", "k > 1"])

plt.ylim(0, 0.02)

plt.xlabel("epoch")
plt.ylabel("validation loss")

plt.savefig("graphs/qho_small_learning_curves.pdf", bbox_inches="tight")

plt.show()
