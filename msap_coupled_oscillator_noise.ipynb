# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import torch
import os

from train import train_MSAP
from dist_matrix import gen_dist_matrix

import matplotlib.pyplot as plt
plt.rcParams["font.size"] = 15

# %%
co = np.load("data/coupled_oscillator.npz")

data = co["data"]
E = co["E"]

idx = np.random.choice(range(len(data)), size=5)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for i in [0, 1]:
    for j in idx:
        axes[i].scatter(*data[j][:, [i, i + 2]].T, s=1, label=f"E1={round(E[j][0], 1)}, E2={round(E[j][1], 1)}")
    axes[i].set_xlabel(f"x{i + 1}")
    axes[i].set_ylabel(f"p{i + 1}")
    axes[i].legend()

plt.savefig("graphs/co_traj.pdf")

plt.show()

# %%
noise_std_lst = np.exp(-np.arange(6) / 2) * np.exp(1 / 2)

data = StandardScaler().fit_transform(data.reshape(data.shape[0] * data.shape[1], -1)).reshape(data.shape)

valid_size = len(data) // 5
train_size = len(data) - valid_size

train_idx, valid_idx = train_test_split(torch.arange(len(data)), test_size=valid_size)

cfg = {
    "target_dim": 10,
    "intermediate_dim": 16,
    "intermediate_layers": 2,
}

models_lst = []
losses_lst = []
for noise_std in noise_std_lst:
    noisy_data = data + np.random.normal(size=data.shape) * noise_std
    
    name = f"co_noise_{round(noise_std, 2)}"
    if os.path.isfile(f"data/{name}_dmat.npz"):
        dmat = np.load(f"data/{name}_dmat.npz")["dmat"]
    else:
        dmat = gen_dist_matrix(noisy_data, name=f"data/{name}")
    
    dmat = torch.tensor(dmat, dtype=torch.float32)
    train_dmat = dmat[train_idx[:, None], train_idx[None, :]]
    valid_dmat = dmat[valid_idx[:, None], train_idx[None, :]]

    models, losses = train_MSAP(train_dmat, valid_dmat, cfg, name + "_v1", min_delta=0.1, patience=50, project_name="MSAP", N_inits=2)

    models_lst.append(models)
    losses_lst.append(losses)
# Out:
# Finished preprocessing 200 events in 0.0030s
#    1990 / 19900  EMDs computed  -  10.00% completed - 109.624s
#    3980 / 19900  EMDs computed  -  20.00% completed - 213.201s
#    5970 / 19900  EMDs computed  -  30.00% completed - 318.789s
#    7960 / 19900  EMDs computed  -  40.00% completed - 425.135s
#    9950 / 19900  EMDs computed  -  50.00% completed - 530.783s
#   11940 / 19900  EMDs computed  -  60.00% completed - 639.880s
#   13930 / 19900  EMDs computed  -  70.00% completed - 744.009s
#   15920 / 19900  EMDs computed  -  80.00% completed - 849.999s
#   17910 / 19900  EMDs computed  -  90.00% completed - 952.026s
#   19900 / 19900  EMDs computed  - 100.00% completed - 1056.505s
# latent_dim: 1
# init #1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: antonii-belyshev (ai-prentice). Use `wandb login --relogin` to force relogin
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_214416-qzxyrzs1</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/qzxyrzs1' target="_blank">co_noise_1.65_v1; latent_dim: 1, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/qzxyrzs1' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/qzxyrzs1</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.2931116223335266
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▃▃▃▄▄▄▅▅▆▆▇▇▇██████▇▇▇▆▆▅▅▄▄▄▄▄▄▃▃▃▃</td></tr><tr><td>r2</td><td>█████▇▇▆▅▅▄▃▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>98</td></tr><tr><td>loss</td><td>0.35064</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00607</td></tr><tr><td>r2</td><td>0.00589</td></tr><tr><td>stress</td><td>0.33868</td></tr><tr><td>trainer/global_step</td><td>23549</td></tr><tr><td>valid_loss</td><td>0.31009</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.65_v1; latent_dim: 1, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/qzxyrzs1' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/qzxyrzs1</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_214416-qzxyrzs1/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113264701432653, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_214907-qqzswv26</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/qqzswv26' target="_blank">co_noise_1.65_v1; latent_dim: 1, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/qqzswv26' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/qqzswv26</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.29875895380973816
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▆▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▃▃▃▄▄▄▄▅▅▆▆▇▇▇████▇▇▆▅▅▅▄▃▃▃▃▃▃▃▂▃▃▂</td></tr><tr><td>r2</td><td>▇█████▇▇▇▆▅▄▄▃▃▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>113</td></tr><tr><td>loss</td><td>0.30201</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00503</td></tr><tr><td>r2</td><td>0.0056</td></tr><tr><td>stress</td><td>0.29138</td></tr><tr><td>trainer/global_step</td><td>27099</td></tr><tr><td>valid_loss</td><td>0.29571</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.65_v1; latent_dim: 1, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/qqzswv26' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/qqzswv26</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_214907-qqzswv26/logs</code>
# best validation loss over latent dim: 0.2931116223335266
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 2
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113619286980894, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_215443-yubh0a6b</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/yubh0a6b' target="_blank">co_noise_1.65_v1; latent_dim: 2, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/yubh0a6b' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/yubh0a6b</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 490
# ------------------------------------
# 891       Trainable params
# 0         Non-trainable params
# 891       Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.03996673971414566
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.026 MB of 0.026 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▁▂▂▂▂▂▂▂▃▄▄▄▄▄▄▅▅▅▆▇▇▇▇▇██████████████</td></tr><tr><td>r2</td><td>███▇▆▅▄▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>169</td></tr><tr><td>loss</td><td>0.08264</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.03108</td></tr><tr><td>r2</td><td>0.00907</td></tr><tr><td>stress</td><td>0.04249</td></tr><tr><td>trainer/global_step</td><td>40449</td></tr><tr><td>valid_loss</td><td>0.04395</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.65_v1; latent_dim: 2, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/yubh0a6b' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/yubh0a6b</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_215443-yubh0a6b/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01111307780051397, max=1.0)…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_220253-fegusx9p</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/fegusx9p' target="_blank">co_noise_1.65_v1; latent_dim: 2, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/fegusx9p' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/fegusx9p</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 490
# ------------------------------------
# 891       Trainable params
# 0         Non-trainable params
# 891       Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.2878619134426117
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.026 MB of 0.026 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▆▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▃▃▃▄▄▄▅▅▅▆▇▇▇█████▇▇▇▆▆▅▅▅▄▄▄▄▄▄▄▄▅▅</td></tr><tr><td>r2</td><td>██▇▆▅▅▄▄▄▃▃▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>115</td></tr><tr><td>loss</td><td>0.29781</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00579</td></tr><tr><td>r2</td><td>0.00673</td></tr><tr><td>stress</td><td>0.28528</td></tr><tr><td>trainer/global_step</td><td>27599</td></tr><tr><td>valid_loss</td><td>0.30891</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.65_v1; latent_dim: 2, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/fegusx9p' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/fegusx9p</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_220253-fegusx9p/logs</code>
# best validation loss over latent dim: 0.03996673971414566
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 3
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112964370598395, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_220834-vdxrkmad</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/vdxrkmad' target="_blank">co_noise_1.65_v1; latent_dim: 3, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/vdxrkmad' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/vdxrkmad</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 506
# ------------------------------------
# 1.1 K     Trainable params
# 0         Non-trainable params
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.03610159456729889
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▄▄▄▅▅▅▄▅▆▅▇▇▇██████████████▇</td></tr><tr><td>r2</td><td>████▇▆▆▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>159</td></tr><tr><td>loss</td><td>0.06248</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.02681</td></tr><tr><td>r2</td><td>0.0081</td></tr><tr><td>stress</td><td>0.02757</td></tr><tr><td>trainer/global_step</td><td>38049</td></tr><tr><td>valid_loss</td><td>0.04327</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.65_v1; latent_dim: 3, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/vdxrkmad' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/vdxrkmad</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_220834-vdxrkmad/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113321853594647, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_221620-qk6xqtg1</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/qk6xqtg1' target="_blank">co_noise_1.65_v1; latent_dim: 3, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/qk6xqtg1' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/qk6xqtg1</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 506
# ------------------------------------
# 1.1 K     Trainable params
# 0         Non-trainable params
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.29036808013916016
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▃▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▃▃▄▄▅▆▇▇█████▇▇▇▆▅▅▅▅▅▄▄▄▄▄▄▄▄▄▄▃▄▄▄▄▄</td></tr><tr><td>r2</td><td>██▇▆▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▃▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>127</td></tr><tr><td>loss</td><td>0.33753</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.0049</td></tr><tr><td>r2</td><td>0.00679</td></tr><tr><td>stress</td><td>0.32585</td></tr><tr><td>trainer/global_step</td><td>30449</td></tr><tr><td>valid_loss</td><td>0.29491</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.65_v1; latent_dim: 3, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/qk6xqtg1' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/qk6xqtg1</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_221620-qk6xqtg1/logs</code>
# best validation loss over latent dim: 0.03610159456729889
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 4
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113086855039, max=1.0)))
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_222237-831h17mi</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/831h17mi' target="_blank">co_noise_1.65_v1; latent_dim: 4, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/831h17mi' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/831h17mi</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 522
# ------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.2939360439777374
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.031 MB of 0.031 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇████████▇▇▇▇▆▆▆▅▅▅▅▅</td></tr><tr><td>r2</td><td>████▇▇▇▇▆▆▆▅▅▅▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>88</td></tr><tr><td>loss</td><td>0.37009</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00541</td></tr><tr><td>r2</td><td>0.00691</td></tr><tr><td>stress</td><td>0.35777</td></tr><tr><td>trainer/global_step</td><td>21149</td></tr><tr><td>valid_loss</td><td>0.307</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.65_v1; latent_dim: 4, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/831h17mi' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/831h17mi</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_222237-831h17mi/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011114124907180667, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_222702-din96jy9</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/din96jy9' target="_blank">co_noise_1.65_v1; latent_dim: 4, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/din96jy9' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/din96jy9</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 522
# ------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.29094716906547546
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.031 MB of 0.031 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▃▃▃▃▄▄▄▄▅▅▅▆▆▆▇▇▇███████▇▇▇▆▆▆▆▅▅▅▅▅</td></tr><tr><td>r2</td><td>███████▇▇▇▇▆▆▆▅▅▄▄▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>95</td></tr><tr><td>loss</td><td>0.32443</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00532</td></tr><tr><td>r2</td><td>0.0074</td></tr><tr><td>stress</td><td>0.31171</td></tr><tr><td>trainer/global_step</td><td>22799</td></tr><tr><td>valid_loss</td><td>0.31798</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.65_v1; latent_dim: 4, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/din96jy9' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/din96jy9</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_222702-din96jy9/logs</code>
# best validation loss over latent dim: 0.29094716906547546
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 1
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113273119553924, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_223147-f58mdplk</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/f58mdplk' target="_blank">co_noise_1.0_v1; latent_dim: 1, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/f58mdplk' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/f58mdplk</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.2662718892097473
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▃▄▄▅▅▅▅▆▆▆▇▇▇███████▇▇▇▆▆▅▅▅▄▄▃▃▄▃▃▃▃▃</td></tr><tr><td>r2</td><td>▇███████▇▇▆▆▅▅▄▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>83</td></tr><tr><td>loss</td><td>0.30568</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.0044</td></tr><tr><td>r2</td><td>0.00596</td></tr><tr><td>stress</td><td>0.29532</td></tr><tr><td>trainer/global_step</td><td>19949</td></tr><tr><td>valid_loss</td><td>0.28133</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.0_v1; latent_dim: 1, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/f58mdplk' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/f58mdplk</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_223147-f58mdplk/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113258120086457, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_223558-kt1kllu1</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/kt1kllu1' target="_blank">co_noise_1.0_v1; latent_dim: 1, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/kt1kllu1' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/kt1kllu1</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 474
# ------------------------------------
# 675       Trainable params
# 0         Non-trainable params
# 675       Total params
# 0.003     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.2621777653694153
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.023 MB of 0.023 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▄▅▅▆▇▇▇▇▇██████▇▇▆▆▅▅▅▄▄▄▃▄▃▃▃▄▃▃▄▃▃▃▄</td></tr><tr><td>r2</td><td>▇▇████████▇▇▆▆▅▄▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▃▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>114</td></tr><tr><td>loss</td><td>0.39367</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00397</td></tr><tr><td>r2</td><td>0.006</td></tr><tr><td>stress</td><td>0.3837</td></tr><tr><td>trainer/global_step</td><td>27349</td></tr><tr><td>valid_loss</td><td>0.26978</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_1.0_v1; latent_dim: 1, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/kt1kllu1' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/kt1kllu1</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_223558-kt1kllu1/logs</code>
# best validation loss over latent dim: 0.2621777653694153
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 2
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113249412220385, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_224143-gg3sc7qr</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/gg3sc7qr' target="_blank">co_noise_1.0_v1; latent_dim: 2, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/gg3sc7qr' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/gg3sc7qr</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 490
# ------------------------------------
# 891       Trainable params
# 0         Non-trainable params
# 891       Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.039783820509910583
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.026 MB of 0.026 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
#  View run <strong style="color:#cdcd00">co_noise_0.61_v1; latent_dim: 2, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/p2mf1ei5' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/p2mf1ei5</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_233239-p2mf1ei5/logs</code>
# init #2
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113952953989308, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_233719-12w8qcbp</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/12w8qcbp' target="_blank">co_noise_0.61_v1; latent_dim: 2, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/12w8qcbp' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/12w8qcbp</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 490
# ------------------------------------
# 891       Trainable params
# 0         Non-trainable params
# 891       Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.2172418087720871
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.026 MB of 0.026 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▂▃▃▄▃▄▄▄▅▅▅▆▆▇▇▇▇██████▇▇▇▆▆▆▆▆▅▅▅▅▅▅▅▅</td></tr><tr><td>r2</td><td>█████▇▇▇▆▆▆▅▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>88</td></tr><tr><td>loss</td><td>0.31842</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.00579</td></tr><tr><td>r2</td><td>0.00791</td></tr><tr><td>stress</td><td>0.30473</td></tr><tr><td>trainer/global_step</td><td>21149</td></tr><tr><td>valid_loss</td><td>0.22954</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.61_v1; latent_dim: 2, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/12w8qcbp' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/12w8qcbp</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_233719-12w8qcbp/logs</code>
# best validation loss over latent dim: 0.2172418087720871
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 3
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01111406792058713, max=1.0)…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_234144-omak0n1r</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/omak0n1r' target="_blank">co_noise_0.61_v1; latent_dim: 3, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/omak0n1r' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/omak0n1r</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 506
# ------------------------------------
# 1.1 K     Trainable params
# 0         Non-trainable params
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.03707810491323471
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▆█▅▄▄▄▃▂▂▂▂▂▂▂▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▃▄▄▅▅▅▅▅▅▅▅▆▅▅▅▅▅▅▅▅████████▇▇██▇▇█</td></tr><tr><td>r2</td><td>███▇▆▆▅▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>▆█▅▄▄▃▃▂▂▂▂▂▂▂▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▂▁▁▂▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▅▄▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>133</td></tr><tr><td>loss</td><td>0.04772</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.01261</td></tr><tr><td>r2</td><td>0.00737</td></tr><tr><td>stress</td><td>0.02775</td></tr><tr><td>trainer/global_step</td><td>31849</td></tr><tr><td>valid_loss</td><td>0.03892</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.61_v1; latent_dim: 3, init #1</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/omak0n1r' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/omak0n1r</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_234144-omak0n1r/logs</code>
# init #2
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_234818-lqie2xli</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/lqie2xli' target="_blank">co_noise_0.61_v1; latent_dim: 3, init #2</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/lqie2xli' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/lqie2xli</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 506
# ------------------------------------
# 1.1 K     Trainable params
# 0         Non-trainable params
# 1.1 K     Total params
# 0.004     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.03695371001958847
# ------------------------------------------------------------------------
# VBox(children=(Label(value='0.028 MB of 0.028 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▄▄▃▃▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>p</td><td>█▅▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>r1</td><td>▁▁▂▂▂▂▃▃▄▅▅▅▅▆▆▅▅▅▅▅▅▅▅▇██▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>r2</td><td>███▇▇▆▅▄▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>stress</td><td>█▅▃▄▄▃▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▅▅▅▄▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>147</td></tr><tr><td>loss</td><td>0.05489</td></tr><tr><td>p</td><td>1.1</td></tr><tr><td>r1</td><td>0.01279</td></tr><tr><td>r2</td><td>0.00748</td></tr><tr><td>stress</td><td>0.03462</td></tr><tr><td>trainer/global_step</td><td>35199</td></tr><tr><td>valid_loss</td><td>0.03727</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">co_noise_0.61_v1; latent_dim: 3, init #2</strong> at: <a href='https://wandb.ai/ai-prentice/MSAP/runs/lqie2xli' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/lqie2xli</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240314_234818-lqie2xli/logs</code>
# best validation loss over latent dim: 0.03695371001958847
# ---------------------------------------------------------------------------
#
#
#
#
# latent_dim: 4
# init #1
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113415254900854, max=1.0…
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/coder/project/wandb/run-20240314_235540-xk71g7w1</code>
# Syncing run <strong><a href='https://wandb.ai/ai-prentice/MSAP/runs/xk71g7w1' target="_blank">co_noise_0.61_v1; latent_dim: 4, init #1</a></strong> to <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ai-prentice/MSAP' target="_blank">https://wandb.ai/ai-prentice/MSAP</a>
#  View run at <a href='https://wandb.ai/ai-prentice/MSAP/runs/xk71g7w1' target="_blank">https://wandb.ai/ai-prentice/MSAP/runs/xk71g7w1</a>
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/loggers/wandb.py:347: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params
# ------------------------------------
# 0 | decoder | Decoder | 522
# ------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# best validation loss: 0.034956194460392
# ------------------------------------------------------------------------

# %%
from matplotlib.lines import Line2D


plt.figure(figsize=(8, 5))
for i, loss_seq in enumerate(np.array(losses_lst).T):
    c = "grey"
    if i == 0:
        c = "red"
    if i == 1:
        c = "green"
    plt.plot(noise_std_lst, loss_seq, c=c)

bound = np.array(losses_lst).T[0] / 3 + 2 * np.array(losses_lst).T[-1] / 3

plt.plot(noise_std_lst, bound, color="b", linestyle="--")
plt.fill_between(noise_std_lst, bound, color="blue", alpha=0.1)

# plt.xticks(noise_std_lst)
plt.xlabel("noise std")

plt.yticks(np.linspace(0, 0.2, 5))
plt.ylabel("final validation loss")

custom_lines = [Line2D([0], [0], color="red", lw=1),
                Line2D([0], [0], color="green", lw=1),
                Line2D([0], [0], color="gray", lw=1)]

plt.legend(custom_lines, ["k = 1", "k = 2", "k > 2"])

plt.savefig("graphs/co_noise_loss.pdf")

plt.show()

# %%
for models in models_lst:
    plt.figure()
    plt.scatter(*models[1].latent.cpu().detach().T, c=E[train_idx, 0])
    plt.show()
